# %% [markdown]
# <a href="https://colab.research.google.com/github/rianachatterjee04/GenAssist/blob/main/Centerpoint_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing Dependencies

# %%
# !pip install ultralytics

# !pip install yt-dlp

# !pip install opencv-python
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.75)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.11/dist-packages (2025.1.26)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)

# %% [markdown]
# Proximity Detector

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import os

class ProximityDetector:
    def __init__(self):
        # Only need YOLO for object detection
        self.walkable_model = YOLO('walkable_model.pt')  # For walkable areas
        self.object_model = YOLO('yolov8n-seg.pt')
        # Define immediate proximity zone (area right in front)
        self.proximity_height = 0.4  # Bottom 40% of frame
        self.proximity_width = 0.4   # Center 40% of frame width

    def is_in_proximity(self, box, frame_shape):
        """Check if object is very close to robot's path"""
        height, width = frame_shape[:2]

        # Get box coordinates
        x1, y1, x2, y2 = box
        box_center_x = (x1 + x2) / 2
        box_bottom = y2

        # Define immediate front zone
        zone_left = width * (0.5 - self.proximity_width/2)
        zone_right = width * (0.5 + self.proximity_width/2)
        zone_top = height * (1 - self.proximity_height)

        # Check if object is in immediate front zone
        if (zone_left < box_center_x < zone_right and box_bottom > zone_top):
            relative_distance = (box_bottom - zone_top) / (height - zone_top)
            return True, relative_distance
        return False, 0

    def process_frame(self, frame):
        height, width = frame.shape[:2]
        processed = frame.copy()

        # Detect and track objects
        results = self.model.track(frame, persist=True)[0]

        if results.boxes is not None:
            boxes = results.boxes.xyxy.cpu().numpy()
            classes = results.boxes.cls.cpu().numpy()

            # Track closest obstacle
            closest_distance = 0
            has_close_obstacle = False

            for box, cls in zip(boxes, classes):
                class_name = self.model.names[int(cls)]

                # Only consider person, bicycle, car as obstacles
                if class_name in ['person', 'bicycle', 'car']:
                    in_proximity, distance = self.is_in_proximity(box, frame.shape)

                    if in_proximity and distance > 0.3:  # Object significantly in front
                        has_close_obstacle = True
                        if distance > closest_distance:
                            closest_distance = distance
                            # Draw red box around closest obstacle
                            cv2.rectangle(processed,
                                        (int(box[0]), int(box[1])),
                                        (int(box[2]), int(box[3])),
                                        (0, 0, 255), 2)

            # Add warning text if obstacle detected
            if has_close_obstacle:
                warning_text = "Obstacle ahead, please move"
                text_size = cv2.getTextSize(warning_text, cv2.FONT_HERSHEY_SIMPLEX, 1.2, 3)[0]
                text_x = (width - text_size[0]) // 2
                cv2.putText(processed, warning_text,
                          (text_x, height - 50),
                          cv2.FONT_HERSHEY_SIMPLEX, 1.2,
                          (0, 0, 255), 3)

        return processed

# %% [markdown]
# Test on Video

# %%
import cv2
import os

# Open your video
cap = cv2.VideoCapture("outside_1.MOV")  # Use the correct filename with .MOV
if not cap.isOpened():
    print("Could not open video")
    print("Current directory:", os.getcwd())
    print("Files in directory:", os.listdir())
    exit()

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create video writer (use the same extension as input)
out = cv2.VideoWriter('output.MOV', cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# Process each frame
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Simply write the original frame
    out.write(frame)
    frame_count += 1

    # Optional: print progress
    if frame_count % 30 == 0:
        print(f"Processed {frame_count} frames")

# Release resources
cap.release()
out.release()

# Verify file creation
if os.path.exists('output.MOV'):
    print(f"Video saved successfully. File size: {os.path.getsize('output.MOV')} bytes")
else:
    print("Failed to create output video")

# Download the video
from google.colab import files
files.download('output.MOV')
# Out:
# Processed 30 frames
# Processed 60 frames
# Processed 90 frames
# Processed 120 frames
# Processed 150 frames
# Processed 180 frames
# Processed 210 frames
# Processed 240 frames
# Processed 270 frames
# Processed 300 frames
# Processed 330 frames
# Processed 360 frames
# Processed 390 frames
# Processed 420 frames
# Processed 450 frames
# Processed 480 frames
# Processed 510 frames
# Processed 540 frames
# Processed 570 frames
# Processed 600 frames
# Processed 630 frames
# Processed 660 frames
# Processed 690 frames
# Processed 720 frames
# Processed 750 frames
# Processed 780 frames
# Processed 810 frames
# Processed 840 frames
# Processed 870 frames
# Processed 900 frames
# Processed 930 frames
# Processed 960 frames
# Processed 990 frames
# Processed 1020 frames
# Processed 1050 frames
# Processed 1080 frames
# Processed 1110 frames
# Processed 1140 frames
# Processed 1170 frames
# Processed 1200 frames
# Processed 1230 frames
# Processed 1260 frames
# Processed 1290 frames
# Processed 1320 frames
# Processed 1350 frames
# Processed 1380 frames
# Processed 1410 frames
# Processed 1440 frames
# Processed 1470 frames
# Processed 1500 frames
# Processed 1530 frames
# Processed 1560 frames
# Processed 1590 frames
# Processed 1620 frames
# Processed 1650 frames
# Processed 1680 frames
# Processed 1710 frames
# Processed 1740 frames
# Processed 1770 frames
# Processed 1800 frames
# Processed 1830 frames
# Processed 1860 frames
# Processed 1890 frames
# Processed 1920 frames
# Processed 1950 frames
# Processed 1980 frames
# Processed 2010 frames
# Processed 2040 frames
# Processed 2070 frames
# Processed 2100 frames
# Processed 2130 frames
# Processed 2160 frames
# Processed 2190 frames
# Processed 2220 frames
# Processed 2250 frames
# Processed 2280 frames
# Processed 2310 frames
# Processed 2340 frames
# Processed 2370 frames
# Processed 2400 frames
# Video saved successfully. File size: 523636664 bytes

# %% [markdown]
# Object detection/Image Segmentation

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO
import glob

def draw_mask_safely(frame, mask, color, alpha=0.5):
    """Safely draw a mask on a frame with validation"""
    try:
        # Validate mask
        if mask is None or len(mask) < 3:  # Need at least 3 points for a polygon
            return frame

        # Convert to correct format
        mask_points = np.array(mask, dtype=np.int32)
        if mask_points.shape[0] < 3:  # Double-check after conversion
            return frame

        # Create overlay
        overlay = frame.copy()
        cv2.fillPoly(overlay, [mask_points], color)
        return cv2.addWeighted(frame, 1-alpha, overlay, alpha, 0)

    except Exception as e:
        print(f"Warning: Could not draw mask: {e}")
        return frame

# Ensure videos directory exists
os.makedirs("videos", exist_ok=True)

# Load both models
walkable_model = YOLO('walkable_model.pt')
object_model = YOLO('yolov8n-seg.pt')

# Set up video capture
video_path = "outside_1.MOV"  # Direct path to the video
cap = cv2.VideoCapture(video_path)

# Check if video is opened successfully
if not cap.isOpened():
    print(f"Error: Could not open video file {video_path}")
    print("Current directory:", os.getcwd())
    print("Files in directory:", os.listdir())
    exit()

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create output video writer
output_path = 'processed_video.mp4'
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# Process entire video
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    processed_frame = frame.copy()

    # 1. Detect walkable zones with your fine-tuned model
    walkable_results = walkable_model.predict(frame, show=False)
    if walkable_results[0].masks is not None:
        for mask in walkable_results[0].masks.xy:
            # Safely draw walkable zones
            processed_frame = draw_mask_safely(
                processed_frame,
                mask,
                color=(0, 255, 0),  # Green for walkable zones
                alpha=0.3
            )
            # Add outline if mask is valid
            if len(mask) >= 3:
                cv2.polylines(processed_frame, [np.int32(mask)], True, (0, 255, 0), 2)

    # 2. Detect and track objects with original model
    object_results = object_model.track(frame, persist=True)[0]
    if object_results.boxes is not None and object_results.masks is not None:
        masks = object_results.masks.xy
        track_ids = object_results.boxes.id.cpu().numpy() if object_results.boxes.id is not None else None
        classes = object_results.boxes.cls.cpu().numpy()

        for i, (mask, cls) in enumerate(zip(masks, classes)):
            # Safely draw objects
            processed_frame = draw_mask_safely(
                processed_frame,
                mask,
                color=(255, 165, 0),  # Orange for objects
                alpha=0.5
            )

            # Add tracking ID and label
            if track_ids is not None and len(mask) > 0:
                track_id = int(track_ids[i])
                class_name = object_model.names[int(cls)]
                label = f"ID {track_id} - {class_name}"
                x_min, y_min = mask.min(axis=0)
                cv2.putText(processed_frame, label,
                          (int(x_min), int(y_min) - 10),
                          cv2.FONT_HERSHEY_SIMPLEX,
                          0.6,
                          (255, 255, 255),
                          2)

    out.write(processed_frame)
    frame_count += 1
    if frame_count % 30 == 0:
        print(f"Processed frame {frame_count}")

cap.release()
out.release()

# Download the processed video
from google.colab import files
files.download('processed_video.mp4')
# Out:
# 0: 384x640 1 walkable-zone, 403.7ms
# Speed: 23.7ms preprocess, 403.7ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 640)
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ultralytics/trackers/utils/matching.py in <module>
#       9 try:
# ---> 10     import lap  # for linear_assignment
#      11
#
# ModuleNotFoundError: No module named 'lap'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d68f503f186e> in <cell line: 0>()
#      78
#      79     # 2. Detect and track objects with original model
# ---> 80     object_results = object_model.track(frame, persist=True)[0]
#      81     if object_results.boxes is not None and object_results.masks is not None:
#      82         masks = object_results.masks.xy
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in track(self, source, stream, persist, **kwargs)
#     598         """
#     599         if not hasattr(self.predictor, "trackers"):
# --> 600             from ultralytics.trackers import register_tracker
#     601
#     602             register_tracker(self, persist)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/trackers/__init__.py in <module>
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#       2
# ----> 3 from .bot_sort import BOTSORT
#       4 from .byte_tracker import BYTETracker
#       5 from .track import register_tracker
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/trackers/bot_sort.py in <module>
#       6
#       7 from .basetrack import TrackState
# ----> 8 from .byte_tracker import BYTETracker, STrack
#       9 from .utils import matching
#      10 from .utils.gmc import GMC
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/trackers/byte_tracker.py in <module>
#       6 from ..utils.ops import xywh2ltwh
#       7 from .basetrack import BaseTrack, TrackState
# ----> 8 from .utils import matching
#       9 from .utils.kalman_filter import KalmanFilterXYAH
#      10
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/trackers/utils/matching.py in <module>
#      15
#      16     check_requirements("lap>=0.5.12")  # https://github.com/gatagat/lap
# ---> 17     import lap
#      18
#      19
#
# ModuleNotFoundError: No module named 'lap'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Combines Both

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO

class ProximityDetector:
    def __init__(self):
        # Load models
        self.walkable_model = YOLO('walkable_model.pt')  # For walkable areas
        self.object_model = YOLO('yolov8n-seg.pt')

        # Define immediate proximity zone (area right in front)
        self.proximity_height = 0.4  # Bottom 40% of frame
        self.proximity_width = 0.4   # Center 40% of frame width

    def draw_mask_safely(self, frame, mask, color, alpha=0.5):
        """Safely draw a mask on a frame with validation"""
        try:
            # Validate mask
            if mask is None or len(mask) < 3:  # Need at least 3 points for a polygon
                return frame

            # Convert to correct format
            mask_points = np.array(mask, dtype=np.int32)
            if mask_points.shape[0] < 3:  # Double-check after conversion
                return frame

            # Create overlay
            overlay = frame.copy()
            cv2.fillPoly(overlay, [mask_points], color)
            return cv2.addWeighted(frame, 1-alpha, overlay, alpha, 0)

        except Exception as e:
            print(f"Warning: Could not draw mask: {e}")
            return frame

    def is_in_proximity(self, box, frame_shape):
        """Check if object is very close to robot's path"""
        height, width = frame_shape[:2]
        # Get box coordinates
        x1, y1, x2, y2 = box
        box_center_x = (x1 + x2) / 2
        box_bottom = y2

        # Define immediate front zone
        zone_left = width * (0.5 - self.proximity_width/2)
        zone_right = width * (0.5 + self.proximity_width/2)
        zone_top = height * (1 - self.proximity_height)

        # Check if object is in immediate front zone
        if (zone_left < box_center_x < zone_right and box_bottom > zone_top):
            relative_distance = (box_bottom - zone_top) / (height - zone_top)
            return True, relative_distance
        return False, 0

    def process_frame(self, frame):
        height, width = frame.shape[:2]
        processed = frame.copy()

        # 1. Detect walkable zones
        walkable_results = self.walkable_model.predict(frame, show=False)
        if walkable_results[0].masks is not None:
            for mask in walkable_results[0].masks.xy:
                # Safely draw walkable zones
                processed = self.draw_mask_safely(
                    processed,
                    mask,
                    color=(0, 255, 0),  # Green for walkable zones
                    alpha=0.3
                )
                # Add outline if mask is valid
                if len(mask) >= 3:
                    cv2.polylines(processed, [np.int32(mask)], True, (0, 255, 0), 2)

        # 2. Detect and track objects
        object_results = self.object_model.track(frame, persist=True)[0]

        # Track closest obstacle
        closest_distance = 0
        has_close_obstacle = False

        if object_results.boxes is not None and object_results.masks is not None:
            boxes = object_results.boxes.xyxy.cpu().numpy()
            classes = object_results.boxes.cls.cpu().numpy()
            masks = object_results.masks.xy
            track_ids = object_results.boxes.id.cpu().numpy() if object_results.boxes.id is not None else None

            for i, (box, cls, mask) in enumerate(zip(boxes, classes, masks)):
                # Safely draw objects
                processed = self.draw_mask_safely(
                    processed,
                    mask,
                    color=(255, 165, 0),  # Orange for objects
                    alpha=0.5
                )

                # Add tracking ID and label
                if track_ids is not None and len(mask) > 0:
                    track_id = int(track_ids[i])
                    class_name = self.object_model.names[int(cls)]
                    label = f"ID {track_id} - {class_name}"
                    x_min, y_min = mask.min(axis=0)
                    cv2.putText(processed, label,
                              (int(x_min), int(y_min) - 10),
                              cv2.FONT_HERSHEY_SIMPLEX,
                              0.6,
                              (255, 255, 255),
                              2)

                # Check proximity for specific obstacle classes
                class_name = self.object_model.names[int(cls)]
                if class_name in ['person', 'bicycle', 'car']:
                    in_proximity, distance = self.is_in_proximity(box, frame.shape)
                    if in_proximity and distance > 0.3:  # Object significantly in front
                        has_close_obstacle = True
                        if distance > closest_distance:
                            closest_distance = distance

                        # Draw red box around closest obstacle
                        cv2.rectangle(processed,
                            (int(box[0]), int(box[1])),
                            (int(box[2]), int(box[3])),
                            (0, 0, 255), 2)

            # Add warning text if obstacle detected
            if has_close_obstacle:
                warning_text = "Obstacle ahead, please move"
                text_size = cv2.getTextSize(warning_text, cv2.FONT_HERSHEY_SIMPLEX, 1.2, 3)[0]
                text_x = (width - text_size[0]) // 2
                cv2.putText(processed, warning_text,
                          (text_x, height - 50),
                          cv2.FONT_HERSHEY_SIMPLEX, 1.2,
                          (0, 0, 255), 3)

        return processed

# %% [markdown]
# Test on Video

# %%
def process_video(input_path, output_path):
    # Ensure videos directory exists
    os.makedirs("videos", exist_ok=True)

    # Create detector
    detector = ProximityDetector()

    # Set up video capture
    cap = cv2.VideoCapture(input_path)

    # Check if video is opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video file {input_path}")
        print("Current directory:", os.getcwd())
        print("Files in directory:", os.listdir())
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Create output video writer
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    # Process entire video
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Process frame
        processed_frame = detector.process_frame(frame)

        # Write processed frame
        out.write(processed_frame)
        frame_count += 1

        if frame_count % 30 == 0:
            print(f"Processed frame {frame_count}")

    # Release resources
    cap.release()
    out.release()

# Main execution
if __name__ == "__main__":
    input_video = "first_floor.MOV"
    output_video = 'processed_video.mp4'

    # Process the video
    process_video(input_video, output_video)

    # Download the processed video
    from google.colab import files
    files.download(output_video)
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 4.0ms preprocess, 180.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 200.1ms
# Speed: 4.2ms preprocess, 200.1ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 330
#
# 0: 384x640 1 walkable-zone, 185.7ms
# Speed: 5.3ms preprocess, 185.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 190.1ms
# Speed: 4.8ms preprocess, 190.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.8ms
# Speed: 5.0ms preprocess, 188.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 209.8ms
# Speed: 4.3ms preprocess, 209.8ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.7ms
# Speed: 5.4ms preprocess, 182.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 197.5ms
# Speed: 4.7ms preprocess, 197.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.7ms
# Speed: 8.3ms preprocess, 182.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 212.4ms
# Speed: 3.9ms preprocess, 212.4ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.3ms
# Speed: 4.3ms preprocess, 196.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 210.8ms
# Speed: 4.1ms preprocess, 210.8ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 183.3ms
# Speed: 4.3ms preprocess, 183.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 197.6ms
# Speed: 5.0ms preprocess, 197.6ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.9ms
# Speed: 4.3ms preprocess, 185.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 205.6ms
# Speed: 4.2ms preprocess, 205.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 176.8ms
# Speed: 5.4ms preprocess, 176.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 201.0ms
# Speed: 4.5ms preprocess, 201.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.2ms
# Speed: 6.6ms preprocess, 182.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 potted plant, 204.7ms
# Speed: 4.6ms preprocess, 204.7ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.4ms
# Speed: 4.7ms preprocess, 186.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 200.2ms
# Speed: 6.5ms preprocess, 200.2ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 187.4ms
# Speed: 4.3ms preprocess, 187.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 204.8ms
# Speed: 4.1ms preprocess, 204.8ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 184.5ms
# Speed: 5.0ms preprocess, 184.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 209.5ms
# Speed: 4.5ms preprocess, 209.5ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.8ms
# Speed: 5.4ms preprocess, 186.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 209.1ms
# Speed: 4.5ms preprocess, 209.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.1ms
# Speed: 4.0ms preprocess, 192.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 197.0ms
# Speed: 4.1ms preprocess, 197.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.6ms
# Speed: 4.3ms preprocess, 198.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 potted plant, 203.7ms
# Speed: 4.1ms preprocess, 203.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.5ms
# Speed: 4.2ms preprocess, 185.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 197.0ms
# Speed: 6.0ms preprocess, 197.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.2ms
# Speed: 5.2ms preprocess, 189.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 204.4ms
# Speed: 4.1ms preprocess, 204.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.4ms
# Speed: 12.1ms preprocess, 182.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 223.1ms
# Speed: 4.1ms preprocess, 223.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 271.4ms
# Speed: 4.0ms preprocess, 271.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 293.1ms
# Speed: 4.4ms preprocess, 293.1ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 284.6ms
# Speed: 14.1ms preprocess, 284.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 322.5ms
# Speed: 4.2ms preprocess, 322.5ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 291.2ms
# Speed: 4.2ms preprocess, 291.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 306.0ms
# Speed: 5.4ms preprocess, 306.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 287.7ms
# Speed: 4.3ms preprocess, 287.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 307.0ms
# Speed: 4.3ms preprocess, 307.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 204.7ms
# Speed: 6.2ms preprocess, 204.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 193.0ms
# Speed: 5.4ms preprocess, 193.0ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.9ms
# Speed: 4.6ms preprocess, 186.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 194.2ms
# Speed: 4.2ms preprocess, 194.2ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 213.9ms
# Speed: 4.6ms preprocess, 213.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 197.4ms
# Speed: 4.7ms preprocess, 197.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.7ms
# Speed: 4.2ms preprocess, 188.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 197.2ms
# Speed: 4.9ms preprocess, 197.2ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 194.0ms
# Speed: 9.0ms preprocess, 194.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 194.8ms
# Speed: 4.2ms preprocess, 194.8ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.5ms
# Speed: 4.4ms preprocess, 193.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 196.2ms
# Speed: 4.2ms preprocess, 196.2ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.6ms
# Speed: 4.9ms preprocess, 190.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 191.5ms
# Speed: 4.9ms preprocess, 191.5ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.3ms
# Speed: 6.4ms preprocess, 186.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 188.0ms
# Speed: 5.3ms preprocess, 188.0ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 360
#
# 0: 384x640 1 walkable-zone, 178.9ms
# Speed: 4.9ms preprocess, 178.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 193.1ms
# Speed: 5.3ms preprocess, 193.1ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 187.9ms
# Speed: 4.3ms preprocess, 187.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 2 potted plants, 206.9ms
# Speed: 4.1ms preprocess, 206.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.3ms
# Speed: 5.9ms preprocess, 185.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 187.2ms
# Speed: 4.9ms preprocess, 187.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 187.9ms
# Speed: 4.2ms preprocess, 187.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 202.0ms
# Speed: 7.2ms preprocess, 202.0ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.0ms
# Speed: 4.2ms preprocess, 190.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 188.0ms
# Speed: 4.2ms preprocess, 188.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.6ms
# Speed: 4.0ms preprocess, 185.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 209.1ms
# Speed: 3.2ms preprocess, 209.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 184.8ms
# Speed: 4.0ms preprocess, 184.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 184.1ms
# Speed: 4.2ms preprocess, 184.1ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.4ms
# Speed: 4.2ms preprocess, 193.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 207.3ms
# Speed: 7.5ms preprocess, 207.3ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 183.8ms
# Speed: 4.2ms preprocess, 183.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 187.7ms
# Speed: 3.7ms preprocess, 187.7ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 187.6ms
# Speed: 4.2ms preprocess, 187.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 211.2ms
# Speed: 3.8ms preprocess, 211.2ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 184.4ms
# Speed: 4.4ms preprocess, 184.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 187.4ms
# Speed: 4.1ms preprocess, 187.4ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 253.8ms
# Speed: 5.3ms preprocess, 253.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 299.0ms
# Speed: 5.4ms preprocess, 299.0ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 283.7ms
# Speed: 4.7ms preprocess, 283.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 300.9ms
# Speed: 4.3ms preprocess, 300.9ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 296.4ms
# Speed: 4.4ms preprocess, 296.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 potted plant, 291.7ms
# Speed: 4.6ms preprocess, 291.7ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 290.1ms
# Speed: 4.9ms preprocess, 290.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 potted plant, 312.4ms
# Speed: 4.3ms preprocess, 312.4ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 251.6ms
# Speed: 4.2ms preprocess, 251.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 192.2ms
# Speed: 4.2ms preprocess, 192.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.2ms
# Speed: 6.8ms preprocess, 192.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 184.2ms
# Speed: 6.9ms preprocess, 184.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.8ms
# Speed: 5.5ms preprocess, 192.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 186.9ms
# Speed: 4.7ms preprocess, 186.9ms inference, 23.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 194.1ms
# Speed: 4.1ms preprocess, 194.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 197.4ms
# Speed: 5.3ms preprocess, 197.4ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 210.1ms
# Speed: 4.5ms preprocess, 210.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 4 potted plants, 193.2ms
# Speed: 4.5ms preprocess, 193.2ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 189.5ms
# Speed: 4.7ms preprocess, 189.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 4 potted plants, 191.1ms
# Speed: 4.7ms preprocess, 191.1ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 193.3ms
# Speed: 5.8ms preprocess, 193.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 198.8ms
# Speed: 4.5ms preprocess, 198.8ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 187.7ms
# Speed: 4.7ms preprocess, 187.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 206.4ms
# Speed: 4.3ms preprocess, 206.4ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 185.5ms
# Speed: 6.4ms preprocess, 185.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 193.4ms
# Speed: 4.1ms preprocess, 193.4ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 191.5ms
# Speed: 4.6ms preprocess, 191.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 208.9ms
# Speed: 4.2ms preprocess, 208.9ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.6ms
# Speed: 4.1ms preprocess, 185.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 212.5ms
# Speed: 4.2ms preprocess, 212.5ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.7ms
# Speed: 4.0ms preprocess, 186.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 202.8ms
# Speed: 4.2ms preprocess, 202.8ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.1ms
# Speed: 5.0ms preprocess, 186.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 202.0ms
# Speed: 6.1ms preprocess, 202.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 195.6ms
# Speed: 4.4ms preprocess, 195.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 193.6ms
# Speed: 4.0ms preprocess, 193.6ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.8ms
# Speed: 4.3ms preprocess, 185.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 201.5ms
# Speed: 4.1ms preprocess, 201.5ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 390
#
# 0: 384x640 1 walkable-zone, 201.2ms
# Speed: 5.0ms preprocess, 201.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 196.5ms
# Speed: 4.8ms preprocess, 196.5ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 183.0ms
# Speed: 4.5ms preprocess, 183.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 203.6ms
# Speed: 4.9ms preprocess, 203.6ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.1ms
# Speed: 4.8ms preprocess, 196.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 194.2ms
# Speed: 4.4ms preprocess, 194.2ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 181.1ms
# Speed: 4.1ms preprocess, 181.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 205.6ms
# Speed: 3.8ms preprocess, 205.6ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 307.7ms
# Speed: 8.2ms preprocess, 307.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 287.6ms
# Speed: 5.1ms preprocess, 287.6ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 297.2ms
# Speed: 4.2ms preprocess, 297.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 313.2ms
# Speed: 5.6ms preprocess, 313.2ms inference, 28.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 291.6ms
# Speed: 5.3ms preprocess, 291.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 316.8ms
# Speed: 4.3ms preprocess, 316.8ms inference, 32.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 281.7ms
# Speed: 4.6ms preprocess, 281.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 302.3ms
# Speed: 4.4ms preprocess, 302.3ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.3ms
# Speed: 4.4ms preprocess, 188.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 189.7ms
# Speed: 4.5ms preprocess, 189.7ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 212.6ms
# Speed: 4.5ms preprocess, 212.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 211.1ms
# Speed: 4.5ms preprocess, 211.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.8ms
# Speed: 5.2ms preprocess, 188.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 182.8ms
# Speed: 4.4ms preprocess, 182.8ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.8ms
# Speed: 4.1ms preprocess, 186.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 213.8ms
# Speed: 5.1ms preprocess, 213.8ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.9ms
# Speed: 4.5ms preprocess, 198.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 2 potted plants, 189.4ms
# Speed: 3.9ms preprocess, 189.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 208.9ms
# Speed: 6.7ms preprocess, 208.9ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 181.6ms
# Speed: 5.9ms preprocess, 181.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 182.6ms
# Speed: 4.7ms preprocess, 182.6ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.3ms
# Speed: 10.5ms preprocess, 190.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 203.3ms
# Speed: 4.0ms preprocess, 203.3ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.6ms
# Speed: 4.7ms preprocess, 188.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 189.3ms
# Speed: 4.1ms preprocess, 189.3ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 203.3ms
# Speed: 4.7ms preprocess, 203.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 196.4ms
# Speed: 4.1ms preprocess, 196.4ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 179.2ms
# Speed: 4.7ms preprocess, 179.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 186.8ms
# Speed: 4.7ms preprocess, 186.8ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 202.4ms
# Speed: 5.9ms preprocess, 202.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 198.1ms
# Speed: 7.4ms preprocess, 198.1ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.3ms
# Speed: 5.0ms preprocess, 190.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 191.3ms
# Speed: 4.1ms preprocess, 191.3ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 204.8ms
# Speed: 4.2ms preprocess, 204.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 193.8ms
# Speed: 3.8ms preprocess, 193.8ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.8ms
# Speed: 4.5ms preprocess, 186.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 197.9ms
# Speed: 5.4ms preprocess, 197.9ms inference, 27.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 203.0ms
# Speed: 5.8ms preprocess, 203.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 182.6ms
# Speed: 5.5ms preprocess, 182.6ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.5ms
# Speed: 5.5ms preprocess, 189.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 197.4ms
# Speed: 4.3ms preprocess, 197.4ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 216.3ms
# Speed: 4.0ms preprocess, 216.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 183.6ms
# Speed: 7.1ms preprocess, 183.6ms inference, 29.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 205.1ms
# Speed: 7.6ms preprocess, 205.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 3 potted plants, 293.5ms
# Speed: 4.4ms preprocess, 293.5ms inference, 36.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 290.0ms
# Speed: 10.7ms preprocess, 290.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 3 potted plants, 302.9ms
# Speed: 4.0ms preprocess, 302.9ms inference, 31.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 298.5ms
# Speed: 4.3ms preprocess, 298.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 potted plants, 1 bed, 284.4ms
# Speed: 5.3ms preprocess, 284.4ms inference, 44.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 313.9ms
# Speed: 7.6ms preprocess, 313.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 3 potted plants, 284.2ms
# Speed: 4.1ms preprocess, 284.2ms inference, 62.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 420
#
# 0: 384x640 1 walkable-zone, 192.1ms
# Speed: 5.7ms preprocess, 192.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 3 potted plants, 187.9ms
# Speed: 5.0ms preprocess, 187.9ms inference, 42.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.8ms
# Speed: 4.3ms preprocess, 189.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 3 potted plants, 201.8ms
# Speed: 4.2ms preprocess, 201.8ms inference, 31.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.0ms
# Speed: 4.3ms preprocess, 197.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 205.7ms
# Speed: 4.0ms preprocess, 205.7ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.0ms
# Speed: 4.0ms preprocess, 192.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 2 potted plants, 207.7ms
# Speed: 4.1ms preprocess, 207.7ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.0ms
# Speed: 5.4ms preprocess, 189.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 3 potted plants, 199.6ms
# Speed: 5.8ms preprocess, 199.6ms inference, 21.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.0ms
# Speed: 5.3ms preprocess, 197.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bench, 2 potted plants, 194.0ms
# Speed: 5.6ms preprocess, 194.0ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 223.7ms
# Speed: 4.4ms preprocess, 223.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 192.1ms
# Speed: 4.2ms preprocess, 192.1ms inference, 25.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 208.0ms
# Speed: 6.4ms preprocess, 208.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 189.8ms
# Speed: 4.2ms preprocess, 189.8ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 210.0ms
# Speed: 4.4ms preprocess, 210.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 185.8ms
# Speed: 4.7ms preprocess, 185.8ms inference, 27.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.2ms
# Speed: 5.2ms preprocess, 192.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 207.2ms
# Speed: 5.9ms preprocess, 207.2ms inference, 23.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 204.0ms
# Speed: 4.4ms preprocess, 204.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bench, 2 potted plants, 205.3ms
# Speed: 4.0ms preprocess, 205.3ms inference, 27.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 207.0ms
# Speed: 4.1ms preprocess, 207.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 potted plants, 1 bed, 204.5ms
# Speed: 4.2ms preprocess, 204.5ms inference, 27.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 199.2ms
# Speed: 6.9ms preprocess, 199.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 3 potted plants, 190.6ms
# Speed: 4.0ms preprocess, 190.6ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.9ms
# Speed: 4.5ms preprocess, 197.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 2 potted plants, 207.7ms
# Speed: 6.0ms preprocess, 207.7ms inference, 21.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 209.5ms
# Speed: 11.7ms preprocess, 209.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 2 potted plants, 194.3ms
# Speed: 4.6ms preprocess, 194.3ms inference, 27.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 210.5ms
# Speed: 4.3ms preprocess, 210.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 204.2ms
# Speed: 4.2ms preprocess, 204.2ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.5ms
# Speed: 4.3ms preprocess, 198.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 191.9ms
# Speed: 4.1ms preprocess, 191.9ms inference, 26.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 217.1ms
# Speed: 9.1ms preprocess, 217.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 295.8ms
# Speed: 4.4ms preprocess, 295.8ms inference, 43.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 296.0ms
# Speed: 4.2ms preprocess, 296.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bench, 3 potted plants, 1 tv, 310.3ms
# Speed: 4.2ms preprocess, 310.3ms inference, 38.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 296.3ms
# Speed: 4.4ms preprocess, 296.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 296.5ms
# Speed: 4.4ms preprocess, 296.5ms inference, 51.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 308.5ms
# Speed: 4.6ms preprocess, 308.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 288.8ms
# Speed: 4.7ms preprocess, 288.8ms inference, 32.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 194.3ms
# Speed: 4.0ms preprocess, 194.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 189.5ms
# Speed: 6.1ms preprocess, 189.5ms inference, 23.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 212.3ms
# Speed: 4.1ms preprocess, 212.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 211.7ms
# Speed: 4.1ms preprocess, 211.7ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.8ms
# Speed: 4.2ms preprocess, 193.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 bed, 1 tv, 187.2ms
# Speed: 4.1ms preprocess, 187.2ms inference, 25.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.4ms
# Speed: 4.7ms preprocess, 196.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 220.5ms
# Speed: 4.3ms preprocess, 220.5ms inference, 23.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.9ms
# Speed: 7.8ms preprocess, 193.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 187.7ms
# Speed: 4.4ms preprocess, 187.7ms inference, 21.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 230.3ms
# Speed: 6.6ms preprocess, 230.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 186.9ms
# Speed: 4.2ms preprocess, 186.9ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.7ms
# Speed: 4.5ms preprocess, 197.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 185.2ms
# Speed: 4.4ms preprocess, 185.2ms inference, 28.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 199.7ms
# Speed: 4.5ms preprocess, 199.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 187.7ms
# Speed: 4.9ms preprocess, 187.7ms inference, 30.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 194.5ms
# Speed: 5.6ms preprocess, 194.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 1 tv, 209.1ms
# Speed: 4.1ms preprocess, 209.1ms inference, 27.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 450
#
# 0: 384x640 1 walkable-zone, 202.2ms
# Speed: 6.6ms preprocess, 202.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 potted plants, 189.1ms
# Speed: 4.2ms preprocess, 189.1ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.5ms
# Speed: 4.5ms preprocess, 197.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 potted plants, 204.3ms
# Speed: 4.2ms preprocess, 204.3ms inference, 27.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.5ms
# Speed: 4.2ms preprocess, 189.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 186.7ms
# Speed: 5.5ms preprocess, 186.7ms inference, 25.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.8ms
# Speed: 4.7ms preprocess, 198.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 refrigerator, 203.6ms
# Speed: 4.2ms preprocess, 203.6ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 194.7ms
# Speed: 4.8ms preprocess, 194.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 refrigerator, 185.8ms
# Speed: 5.2ms preprocess, 185.8ms inference, 26.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 211.9ms
# Speed: 5.3ms preprocess, 211.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 refrigerator, 189.3ms
# Speed: 4.8ms preprocess, 189.3ms inference, 30.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.9ms
# Speed: 4.4ms preprocess, 188.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 bed, 1 refrigerator, 212.2ms
# Speed: 4.5ms preprocess, 212.2ms inference, 29.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 206.6ms
# Speed: 4.4ms preprocess, 206.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 bed, 2 refrigerators, 188.1ms
# Speed: 5.6ms preprocess, 188.1ms inference, 30.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 265.9ms
# Speed: 5.7ms preprocess, 265.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 bed, 2 refrigerators, 301.8ms
# Speed: 4.1ms preprocess, 301.8ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 303.7ms
# Speed: 4.2ms preprocess, 303.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 bed, 1 refrigerator, 285.1ms
# Speed: 4.7ms preprocess, 285.1ms inference, 39.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 282.1ms
# Speed: 4.5ms preprocess, 282.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 bed, 1 refrigerator, 301.0ms
# Speed: 4.4ms preprocess, 301.0ms inference, 46.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 316.1ms
# Speed: 5.7ms preprocess, 316.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 1 refrigerator, 310.5ms
# Speed: 6.0ms preprocess, 310.5ms inference, 21.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.2ms
# Speed: 5.1ms preprocess, 197.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 1 refrigerator, 204.5ms
# Speed: 4.4ms preprocess, 204.5ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.7ms
# Speed: 4.5ms preprocess, 192.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 1 refrigerator, 198.0ms
# Speed: 4.3ms preprocess, 198.0ms inference, 26.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.8ms
# Speed: 5.9ms preprocess, 189.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 1 refrigerator, 191.5ms
# Speed: 9.9ms preprocess, 191.5ms inference, 25.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.5ms
# Speed: 6.9ms preprocess, 198.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 186.2ms
# Speed: 4.7ms preprocess, 186.2ms inference, 24.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 210.5ms
# Speed: 4.2ms preprocess, 210.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 190.0ms
# Speed: 4.8ms preprocess, 190.0ms inference, 22.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 187.5ms
# Speed: 6.3ms preprocess, 187.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 194.8ms
# Speed: 5.6ms preprocess, 194.8ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 204.5ms
# Speed: 8.6ms preprocess, 204.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 4 potted plants, 198.8ms
# Speed: 6.9ms preprocess, 198.8ms inference, 26.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 180.3ms
# Speed: 6.9ms preprocess, 180.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 3 potted plants, 186.4ms
# Speed: 5.8ms preprocess, 186.4ms inference, 27.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.5ms
# Speed: 5.1ms preprocess, 197.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 3 potted plants, 197.3ms
# Speed: 7.4ms preprocess, 197.3ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.1ms
# Speed: 4.4ms preprocess, 186.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 3 potted plants, 204.3ms
# Speed: 4.0ms preprocess, 204.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 201.0ms
# Speed: 6.2ms preprocess, 201.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 3 potted plants, 185.3ms
# Speed: 4.2ms preprocess, 185.3ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 191.6ms
# Speed: 4.3ms preprocess, 191.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 2 potted plants, 203.2ms
# Speed: 4.7ms preprocess, 203.2ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.8ms
# Speed: 9.4ms preprocess, 197.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 chair, 2 potted plants, 187.7ms
# Speed: 4.4ms preprocess, 187.7ms inference, 25.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.9ms
# Speed: 4.2ms preprocess, 198.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 190.4ms
# Speed: 4.0ms preprocess, 190.4ms inference, 32.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 184.6ms
# Speed: 4.3ms preprocess, 184.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 187.4ms
# Speed: 4.4ms preprocess, 187.4ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 205.2ms
# Speed: 4.5ms preprocess, 205.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 209.3ms
# Speed: 4.9ms preprocess, 209.3ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.2ms
# Speed: 6.1ms preprocess, 196.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 187.6ms
# Speed: 3.9ms preprocess, 187.6ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 208.6ms
# Speed: 4.4ms preprocess, 208.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 potted plants, 303.5ms
# Speed: 4.3ms preprocess, 303.5ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 480
#
# 0: 384x640 1 walkable-zone, 295.8ms
# Speed: 4.7ms preprocess, 295.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 296.5ms
# Speed: 7.2ms preprocess, 296.5ms inference, 28.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 295.0ms
# Speed: 10.1ms preprocess, 295.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 297.2ms
# Speed: 4.4ms preprocess, 297.2ms inference, 32.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 304.1ms
# Speed: 8.3ms preprocess, 304.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 301.2ms
# Speed: 4.2ms preprocess, 301.2ms inference, 29.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 214.7ms
# Speed: 4.4ms preprocess, 214.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 190.2ms
# Speed: 4.8ms preprocess, 190.2ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 188.6ms
# Speed: 4.2ms preprocess, 188.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 203.3ms
# Speed: 3.8ms preprocess, 203.3ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.3ms
# Speed: 5.4ms preprocess, 190.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 190.0ms
# Speed: 5.9ms preprocess, 190.0ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.9ms
# Speed: 5.4ms preprocess, 193.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 210.7ms
# Speed: 4.3ms preprocess, 210.7ms inference, 22.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.2ms
# Speed: 12.7ms preprocess, 185.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 182.8ms
# Speed: 5.7ms preprocess, 182.8ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.4ms
# Speed: 5.3ms preprocess, 197.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 204.8ms
# Speed: 4.1ms preprocess, 204.8ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 182.8ms
# Speed: 4.3ms preprocess, 182.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 188.5ms
# Speed: 4.4ms preprocess, 188.5ms inference, 18.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 210.1ms
# Speed: 7.7ms preprocess, 210.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 207.6ms
# Speed: 4.2ms preprocess, 207.6ms inference, 25.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.6ms
# Speed: 4.3ms preprocess, 189.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 197.5ms
# Speed: 3.8ms preprocess, 197.5ms inference, 21.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.4ms
# Speed: 7.0ms preprocess, 196.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 188.3ms
# Speed: 4.7ms preprocess, 188.3ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 189.7ms
# Speed: 4.4ms preprocess, 189.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 197.5ms
# Speed: 5.3ms preprocess, 197.5ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 207.7ms
# Speed: 13.8ms preprocess, 207.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 194.0ms
# Speed: 4.2ms preprocess, 194.0ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.0ms
# Speed: 4.2ms preprocess, 196.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 203.9ms
# Speed: 4.1ms preprocess, 203.9ms inference, 17.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 181.0ms
# Speed: 9.2ms preprocess, 181.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 187.8ms
# Speed: 4.1ms preprocess, 187.8ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 202.3ms
# Speed: 4.3ms preprocess, 202.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 potted plants, 189.3ms
# ...
# Speed: 6.5ms preprocess, 187.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 198.2ms
# Speed: 4.6ms preprocess, 198.2ms inference, 31.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 walkable-zones, 192.3ms
# Speed: 12.8ms preprocess, 192.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.5ms
# Speed: 4.2ms preprocess, 186.5ms inference, 36.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 walkable-zones, 215.4ms
# Speed: 5.3ms preprocess, 215.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 truck, 195.2ms
# Speed: 4.1ms preprocess, 195.2ms inference, 35.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 walkable-zones, 186.6ms
# Speed: 4.4ms preprocess, 186.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 truck, 193.1ms
# Speed: 4.5ms preprocess, 193.1ms inference, 36.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 walkable-zones, 283.3ms
# Speed: 5.8ms preprocess, 283.3ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 car, 1 truck, 306.5ms
# Speed: 5.9ms preprocess, 306.5ms inference, 58.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 300.7ms
# Speed: 6.3ms preprocess, 300.7ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 295.2ms
# Speed: 4.3ms preprocess, 295.2ms inference, 71.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 319.2ms
# Speed: 4.9ms preprocess, 319.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 323.7ms
# Speed: 4.3ms preprocess, 323.7ms inference, 67.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 289.8ms
# Speed: 4.7ms preprocess, 289.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 202.1ms
# Speed: 4.6ms preprocess, 202.1ms inference, 37.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.0ms
# Speed: 4.9ms preprocess, 190.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 194.5ms
# Speed: 4.5ms preprocess, 194.5ms inference, 35.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 187.6ms
# Speed: 5.4ms preprocess, 187.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 213.5ms
# Speed: 6.3ms preprocess, 213.5ms inference, 49.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1110
#
# 0: 384x640 1 walkable-zone, 204.9ms
# Speed: 4.2ms preprocess, 204.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 200.5ms
# Speed: 4.4ms preprocess, 200.5ms inference, 53.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 222.8ms
# Speed: 4.3ms preprocess, 222.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 194.3ms
# Speed: 4.2ms preprocess, 194.3ms inference, 49.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 193.4ms
# Speed: 6.6ms preprocess, 193.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 193.3ms
# Speed: 4.2ms preprocess, 193.3ms inference, 66.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 195.0ms
# Speed: 5.2ms preprocess, 195.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 195.4ms
# Speed: 4.3ms preprocess, 195.4ms inference, 45.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 203.7ms
# Speed: 4.4ms preprocess, 203.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 213.3ms
# Speed: 8.2ms preprocess, 213.3ms inference, 47.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 195.8ms
# Speed: 5.1ms preprocess, 195.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 197.8ms
# Speed: 4.2ms preprocess, 197.8ms inference, 52.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 207.9ms
# Speed: 4.2ms preprocess, 207.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 truck, 196.6ms
# Speed: 3.9ms preprocess, 196.6ms inference, 43.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.3ms
# Speed: 5.2ms preprocess, 196.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 truck, 204.4ms
# Speed: 4.3ms preprocess, 204.4ms inference, 45.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 197.3ms
# Speed: 4.3ms preprocess, 197.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 truck, 203.9ms
# Speed: 4.2ms preprocess, 203.9ms inference, 44.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 202.3ms
# Speed: 8.8ms preprocess, 202.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 202.9ms
# Speed: 5.9ms preprocess, 202.9ms inference, 54.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.2ms
# Speed: 4.9ms preprocess, 190.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 193.4ms
# Speed: 4.7ms preprocess, 193.4ms inference, 42.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 198.7ms
# Speed: 5.3ms preprocess, 198.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 199.6ms
# Speed: 4.3ms preprocess, 199.6ms inference, 49.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.9ms
# Speed: 14.4ms preprocess, 185.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 199.3ms
# Speed: 4.2ms preprocess, 199.3ms inference, 39.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.3ms
# Speed: 4.3ms preprocess, 186.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 206.5ms
# Speed: 4.0ms preprocess, 206.5ms inference, 55.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 304.3ms
# Speed: 10.2ms preprocess, 304.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 288.2ms
# Speed: 4.7ms preprocess, 288.2ms inference, 52.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 284.7ms
# Speed: 11.6ms preprocess, 284.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 292.7ms
# Speed: 4.7ms preprocess, 292.7ms inference, 41.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 305.8ms
# Speed: 9.8ms preprocess, 305.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 313.9ms
# Speed: 4.2ms preprocess, 313.9ms inference, 40.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 295.1ms
# Speed: 8.0ms preprocess, 295.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 208.2ms
# Speed: 4.3ms preprocess, 208.2ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 180.3ms
# Speed: 5.5ms preprocess, 180.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 2 trucks, 201.9ms
# Speed: 6.3ms preprocess, 201.9ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 179.2ms
# Speed: 11.5ms preprocess, 179.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 203.5ms
# Speed: 5.1ms preprocess, 203.5ms inference, 29.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 207.3ms
# Speed: 4.7ms preprocess, 207.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 192.9ms
# Speed: 5.1ms preprocess, 192.9ms inference, 26.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 203.5ms
# Speed: 6.3ms preprocess, 203.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 189.9ms
# Speed: 4.1ms preprocess, 189.9ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 206.9ms
# Speed: 4.3ms preprocess, 206.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 197.6ms
# Speed: 4.6ms preprocess, 197.6ms inference, 27.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.5ms
# Speed: 5.0ms preprocess, 190.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 229.3ms
# Speed: 4.1ms preprocess, 229.3ms inference, 25.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 199.6ms
# Speed: 4.2ms preprocess, 199.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 216.7ms
# Speed: 4.3ms preprocess, 216.7ms inference, 20.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 191.0ms
# Speed: 4.6ms preprocess, 191.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 202.1ms
# Speed: 4.8ms preprocess, 202.1ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 193.7ms
# Speed: 4.3ms preprocess, 193.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 200.0ms
# Speed: 4.0ms preprocess, 200.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.8ms
# Speed: 4.4ms preprocess, 188.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 216.6ms
# Speed: 6.0ms preprocess, 216.6ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 204.2ms
# Speed: 10.2ms preprocess, 204.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 toilet, 195.5ms
# Speed: 6.2ms preprocess, 195.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.5ms
# Speed: 5.1ms preprocess, 188.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 toilet, 2 vases, 212.0ms
# Speed: 5.0ms preprocess, 212.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 1140
#
# 0: 384x640 (no detections), 196.0ms
# Speed: 10.4ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 suitcase, 202.2ms
# Speed: 4.5ms preprocess, 202.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 213.2ms
# Speed: 4.3ms preprocess, 213.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 benchs, 1 suitcase, 1 toilet, 1 vase, 245.1ms
# Speed: 4.7ms preprocess, 245.1ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 297.5ms
# Speed: 6.2ms preprocess, 297.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 304.7ms
# Speed: 7.8ms preprocess, 304.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 315.6ms
# Speed: 4.3ms preprocess, 315.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 vase, 284.5ms
# Speed: 6.0ms preprocess, 284.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 321.8ms
# Speed: 8.4ms preprocess, 321.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 1 toilet, 1 vase, 341.0ms
# Speed: 4.2ms preprocess, 341.0ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 356.5ms
# Speed: 8.3ms preprocess, 356.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 toilet, 2 vases, 340.4ms
# Speed: 7.4ms preprocess, 340.4ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 370.7ms
# Speed: 4.4ms preprocess, 370.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 toilet, 2 vases, 377.0ms
# Speed: 6.2ms preprocess, 377.0ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 287.0ms
# Speed: 7.6ms preprocess, 287.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 2 toilets, 2 vases, 325.8ms
# Speed: 4.6ms preprocess, 325.8ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 290.0ms
# Speed: 4.6ms preprocess, 290.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 boat, 1 toilet, 227.6ms
# Speed: 4.3ms preprocess, 227.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 196.0ms
# Speed: 6.1ms preprocess, 196.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 toilets, 1 vase, 192.9ms
# Speed: 4.4ms preprocess, 192.9ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 192.5ms
# Speed: 4.9ms preprocess, 192.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 toilet, 204.0ms
# Speed: 4.4ms preprocess, 204.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 195.7ms
# Speed: 8.0ms preprocess, 195.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 toilet, 201.9ms
# Speed: 4.7ms preprocess, 201.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 186.2ms
# Speed: 4.2ms preprocess, 186.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 207.7ms
# Speed: 4.4ms preprocess, 207.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 190.5ms
# Speed: 7.3ms preprocess, 190.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 potted plants, 1 toilet, 1 vase, 190.4ms
# Speed: 5.8ms preprocess, 190.4ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 185.2ms
# Speed: 7.6ms preprocess, 185.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 chair, 1 potted plant, 1 vase, 205.4ms
# Speed: 4.1ms preprocess, 205.4ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 177.6ms
# Speed: 5.2ms preprocess, 177.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 potted plant, 1 toilet, 199.5ms
# Speed: 4.2ms preprocess, 199.5ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 195.3ms
# Speed: 5.3ms preprocess, 195.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bench, 1 toilet, 202.4ms
# Speed: 4.4ms preprocess, 202.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 walkable-zone, 180.4ms
# Speed: 5.5ms preprocess, 180.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 potted plant, 1 vase, 189.1ms
# Speed: 3.9ms preprocess, 189.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
