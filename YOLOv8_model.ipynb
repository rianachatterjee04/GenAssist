# %% [markdown]
# <a href="https://colab.research.google.com/github/rianachatterjee04/GenAssist/blob/main/YOLOv8_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics

# %% [markdown]
# Importing YOLOv8

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 911, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.11/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'track', 'train', 'benchmark', 'predict', 'val', 'export'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'detect', 'obb', 'pose', 'classify', 'segment'}
#                 MODE (required) is one of {'track', 'train', 'benchmark', 'predict', 'val', 'export'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco8.yaml model=yolo11n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolo11n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Val a pretrained detection model at batch-size 1 and image size 640:
#         yolo val model=yolo11n.pt data=coco8.yaml batch=1 imgsz=640
#
#     4. Export a YOLO11n classification model to ONNX format at image size 224 by 128 (no TASK required)
#         yolo export model=yolo11n-cls.pt format=onnx imgsz=224,128
#
#     5. Ultralytics solutions usage
#         yolo solutions count or in ['heatmap', 'queue', 'speed', 'workout', 'analytics', 'trackzone', 'inference'] source="path/to/video/file.mp4"
#
#     6. Run special commands:
#         yolo help
#         yolo checks
#         yolo version
#         yolo settings
#         yolo copy-cfg
#         yolo cfg
#         yolo solutions help
#
#     Docs: https://docs.ultralytics.com
#     Solutions: https://docs.ultralytics.com/solutions/
#     Community: https://community.ultralytics.com
#     GitHub: https://github.com/ultralytics/ultralytics
#
# Sentry is attempting to send 2 pending events
# Waiting up to 2 seconds
# Press Ctrl-C to quit

# %% [markdown]
# Train YOLOv8 Model on Custom Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR API KEY")
project = rf.workspace("nicolai-hoirup-nielsen").project

# %% [markdown]
# Installing Dependencies

# %%
# Install yt-dlp for downloading YouTube videos
# !pip install yt-dlp

# Install OpenCV for video frame extraction
# !pip install opencv-python
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.1.15-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 5.3 MB/s eta 0:00:00
# Downloading yt_dlp-2025.1.15-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 47.4 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.1.15
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)

# %% [markdown]
# Downloading Youtube Videos

# %%
import os

os.makedirs("videos", exist_ok = True)

VIDEO_URL = "https://www.youtube.com/watch?v=EVrqJkbV1bw"
# !yt-dlp -o "videos/%(new_york)s.%(ext)s" {VIDEO_URL}

# !ls videos
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RFb6wbsffY0
# [youtube] RFb6wbsffY0: Downloading webpage
# [youtube] RFb6wbsffY0: Downloading tv player API JSON
# [youtube] RFb6wbsffY0: Downloading ios player API JSON
# [youtube] RFb6wbsffY0: Downloading player 6e1dd460
# [youtube] RFb6wbsffY0: Downloading m3u8 information
# [info] RFb6wbsffY0: Downloading 1 format(s): 315+251
# [download] Destination: videos/NA.f315.webm
# [download] 100% of    1.07GiB in 00:00:41 at 26.12MiB/s
# [download] Destination: videos/NA.f251.webm
# [download] 100% of    4.66MiB in 00:00:00 at 30.76MiB/s
# [Merger] Merging formats into "videos/NA.webm"
# Deleting original file videos/NA.f315.webm (pass -k to keep)
# Deleting original file videos/NA.f251.webm (pass -k to keep)
# NA.webm

# %%
# !ls videos
# Out:
# NA.webm

# %% [markdown]
# Extracting frames from the video

# %%
import cv2

# Path to video file
video_path = "videos/NA.webm"  # Replace with the actual video filename
output_dir = "frames"
os.makedirs(output_dir, exist_ok=True)

# Open the video file
vidcap = cv2.VideoCapture(video_path)
success, image = vidcap.read()
frame_rate = 30  # Extract one frame every 30 frames (adjust based on your needs)
count = 0

# Loop through frames
while success:
    if int(vidcap.get(cv2.CAP_PROP_POS_FRAMES)) % frame_rate == 0:
        frame_name = os.path.join(output_dir, f"frame{count}.jpg")
        cv2.imwrite(frame_name, image)  # Save frame as JPEG
        print(f"Saved: {frame_name}")
        count += 1
    success, image = vidcap.read()

print(f"Extracted {count} frames to {output_dir}")
# Out:
# Saved: frames/frame0.jpg
# Saved: frames/frame1.jpg
# Saved: frames/frame2.jpg
# Saved: frames/frame3.jpg
# Saved: frames/frame4.jpg
# Saved: frames/frame5.jpg
# Saved: frames/frame6.jpg
# Saved: frames/frame7.jpg
# Saved: frames/frame8.jpg
# Saved: frames/frame9.jpg
# Saved: frames/frame10.jpg
# Saved: frames/frame11.jpg
# Saved: frames/frame12.jpg
# Saved: frames/frame13.jpg
# Saved: frames/frame14.jpg
# Saved: frames/frame15.jpg
# Saved: frames/frame16.jpg
# Saved: frames/frame17.jpg
# Saved: frames/frame18.jpg
# Saved: frames/frame19.jpg
# Saved: frames/frame20.jpg
# Saved: frames/frame21.jpg
# Saved: frames/frame22.jpg
# Saved: frames/frame23.jpg
# Saved: frames/frame24.jpg
# Saved: frames/frame25.jpg
# Saved: frames/frame26.jpg
# Saved: frames/frame27.jpg
# Saved: frames/frame28.jpg
# Saved: frames/frame29.jpg
# Saved: frames/frame30.jpg
# Saved: frames/frame31.jpg
# Saved: frames/frame32.jpg
# Saved: frames/frame33.jpg
# Saved: frames/frame34.jpg
# Saved: frames/frame35.jpg
# Saved: frames/frame36.jpg
# Saved: frames/frame37.jpg
# Saved: frames/frame38.jpg
# Saved: frames/frame39.jpg
# Saved: frames/frame40.jpg
# Saved: frames/frame41.jpg
# Saved: frames/frame42.jpg
# Saved: frames/frame43.jpg
# Saved: frames/frame44.jpg
# Saved: frames/frame45.jpg
# Saved: frames/frame46.jpg
# Saved: frames/frame47.jpg
# Saved: frames/frame48.jpg
# Saved: frames/frame49.jpg
# Saved: frames/frame50.jpg
# Saved: frames/frame51.jpg
# Saved: frames/frame52.jpg
# Saved: frames/frame53.jpg
# Saved: frames/frame54.jpg
# Saved: frames/frame55.jpg
# Saved: frames/frame56.jpg
# Saved: frames/frame57.jpg
# Saved: frames/frame58.jpg
# Saved: frames/frame59.jpg
# Saved: frames/frame60.jpg
# Saved: frames/frame61.jpg
# Saved: frames/frame62.jpg
# Saved: frames/frame63.jpg
# Saved: frames/frame64.jpg
# Saved: frames/frame65.jpg
# Saved: frames/frame66.jpg
# Saved: frames/frame67.jpg
# Saved: frames/frame68.jpg
# Saved: frames/frame69.jpg
# Saved: frames/frame70.jpg
# Saved: frames/frame71.jpg
# Saved: frames/frame72.jpg
# Saved: frames/frame73.jpg
# Saved: frames/frame74.jpg
# Saved: frames/frame75.jpg
# Saved: frames/frame76.jpg
# Saved: frames/frame77.jpg
# Saved: frames/frame78.jpg
# Saved: frames/frame79.jpg
# Saved: frames/frame80.jpg
# Saved: frames/frame81.jpg
# Saved: frames/frame82.jpg
# Saved: frames/frame83.jpg
# Saved: frames/frame84.jpg
# Saved: frames/frame85.jpg
# Saved: frames/frame86.jpg
# Saved: frames/frame87.jpg
# Saved: frames/frame88.jpg
# Saved: frames/frame89.jpg
# Saved: frames/frame90.jpg
# Saved: frames/frame91.jpg
# Saved: frames/frame92.jpg
# Saved: frames/frame93.jpg
# Saved: frames/frame94.jpg
# Saved: frames/frame95.jpg
# Saved: frames/frame96.jpg
# Saved: frames/frame97.jpg
# Saved: frames/frame98.jpg
# Saved: frames/frame99.jpg
# Saved: frames/frame100.jpg
# Saved: frames/frame101.jpg
# Saved: frames/frame102.jpg
# Saved: frames/frame103.jpg
# Saved: frames/frame104.jpg
# Saved: frames/frame105.jpg
# Saved: frames/frame106.jpg
# Saved: frames/frame107.jpg
# Saved: frames/frame108.jpg
# Saved: frames/frame109.jpg
# Saved: frames/frame110.jpg
# Saved: frames/frame111.jpg
# Saved: frames/frame112.jpg
# Saved: frames/frame113.jpg
# Saved: frames/frame114.jpg
# Saved: frames/frame115.jpg
# Saved: frames/frame116.jpg
# Saved: frames/frame117.jpg
# Saved: frames/frame118.jpg
# Saved: frames/frame119.jpg
# Saved: frames/frame120.jpg
# Saved: frames/frame121.jpg
# Saved: frames/frame122.jpg
# Saved: frames/frame123.jpg
# Saved: frames/frame124.jpg
# Saved: frames/frame125.jpg
# Saved: frames/frame126.jpg
# Saved: frames/frame127.jpg
# Saved: frames/frame128.jpg
# Saved: frames/frame129.jpg
# Saved: frames/frame130.jpg
# Saved: frames/frame131.jpg
# Saved: frames/frame132.jpg
# Saved: frames/frame133.jpg
# Saved: frames/frame134.jpg
# Saved: frames/frame135.jpg
# Saved: frames/frame136.jpg
# Saved: frames/frame137.jpg
# Saved: frames/frame138.jpg
# Saved: frames/frame139.jpg
# Saved: frames/frame140.jpg
# Saved: frames/frame141.jpg
# Saved: frames/frame142.jpg
# Saved: frames/frame143.jpg
# Saved: frames/frame144.jpg
# Saved: frames/frame145.jpg
# Saved: frames/frame146.jpg
# Saved: frames/frame147.jpg
# Saved: frames/frame148.jpg
# Saved: frames/frame149.jpg
# Saved: frames/frame150.jpg
# Saved: frames/frame151.jpg
# Saved: frames/frame152.jpg
# Saved: frames/frame153.jpg
# Saved: frames/frame154.jpg
# Saved: frames/frame155.jpg
# Saved: frames/frame156.jpg
# Saved: frames/frame157.jpg
# Saved: frames/frame158.jpg
# Saved: frames/frame159.jpg
# Saved: frames/frame160.jpg
# Saved: frames/frame161.jpg
# Saved: frames/frame162.jpg
# Saved: frames/frame163.jpg
# Saved: frames/frame164.jpg
# Saved: frames/frame165.jpg
# Saved: frames/frame166.jpg
# Saved: frames/frame167.jpg
# Saved: frames/frame168.jpg
# Saved: frames/frame169.jpg
# Saved: frames/frame170.jpg
# Saved: frames/frame171.jpg
# Saved: frames/frame172.jpg
# Saved: frames/frame173.jpg
# Saved: frames/frame174.jpg
# Saved: frames/frame175.jpg
# Saved: frames/frame176.jpg
# Saved: frames/frame177.jpg
# Saved: frames/frame178.jpg
# Saved: frames/frame179.jpg
# Saved: frames/frame180.jpg
# Saved: frames/frame181.jpg
# Saved: frames/frame182.jpg
# Saved: frames/frame183.jpg
# Saved: frames/frame184.jpg
# Saved: frames/frame185.jpg
# Saved: frames/frame186.jpg
# Saved: frames/frame187.jpg
# Saved: frames/frame188.jpg
# Saved: frames/frame189.jpg
# Saved: frames/frame190.jpg
# Saved: frames/frame191.jpg
# Saved: frames/frame192.jpg
# Saved: frames/frame193.jpg
# Saved: frames/frame194.jpg
# Saved: frames/frame195.jpg
# Saved: frames/frame196.jpg
# Saved: frames/frame197.jpg
# Saved: frames/frame198.jpg
# Saved: frames/frame199.jpg
# Saved: frames/frame200.jpg
# Saved: frames/frame201.jpg
# Saved: frames/frame202.jpg
# Saved: frames/frame203.jpg
# Saved: frames/frame204.jpg
# Saved: frames/frame205.jpg
# Saved: frames/frame206.jpg
# Saved: frames/frame207.jpg
# Saved: frames/frame208.jpg
# Saved: frames/frame209.jpg
# Saved: frames/frame210.jpg
# Saved: frames/frame211.jpg
# Saved: frames/frame212.jpg
# Saved: frames/frame213.jpg
# Saved: frames/frame214.jpg
# Saved: frames/frame215.jpg
# Saved: frames/frame216.jpg
# Saved: frames/frame217.jpg
# Saved: frames/frame218.jpg
# Saved: frames/frame219.jpg
# Saved: frames/frame220.jpg
# Saved: frames/frame221.jpg
# Saved: frames/frame222.jpg
# Saved: frames/frame223.jpg
# Saved: frames/frame224.jpg
# Saved: frames/frame225.jpg
# Saved: frames/frame226.jpg
# Saved: frames/frame227.jpg
# Saved: frames/frame228.jpg
# Saved: frames/frame229.jpg
# Saved: frames/frame230.jpg
# Saved: frames/frame231.jpg
# Saved: frames/frame232.jpg
# Saved: frames/frame233.jpg
# Saved: frames/frame234.jpg
# Saved: frames/frame235.jpg
# Saved: frames/frame236.jpg
# Saved: frames/frame237.jpg
# Saved: frames/frame238.jpg
# Saved: frames/frame239.jpg
# Saved: frames/frame240.jpg
# Saved: frames/frame241.jpg
# Saved: frames/frame242.jpg
# Saved: frames/frame243.jpg
# Saved: frames/frame244.jpg
# Saved: frames/frame245.jpg
# Saved: frames/frame246.jpg
# Saved: frames/frame247.jpg
# Saved: frames/frame248.jpg
# Saved: frames/frame249.jpg
# Saved: frames/frame250.jpg
# Saved: frames/frame251.jpg
# Saved: frames/frame252.jpg
# Saved: frames/frame253.jpg
# Saved: frames/frame254.jpg
# Saved: frames/frame255.jpg
# Saved: frames/frame256.jpg
# Saved: frames/frame257.jpg
# Saved: frames/frame258.jpg
# Saved: frames/frame259.jpg
# Saved: frames/frame260.jpg
# Saved: frames/frame261.jpg
# Saved: frames/frame262.jpg
# Saved: frames/frame263.jpg
# Saved: frames/frame264.jpg
# Saved: frames/frame265.jpg
# Saved: frames/frame266.jpg
# Saved: frames/frame267.jpg
# Saved: frames/frame268.jpg
# Saved: frames/frame269.jpg
# Saved: frames/frame270.jpg
# Saved: frames/frame271.jpg
# Saved: frames/frame272.jpg
# Saved: frames/frame273.jpg
# Saved: frames/frame274.jpg
# Saved: frames/frame275.jpg
# Saved: frames/frame276.jpg
# Saved: frames/frame277.jpg
# Saved: frames/frame278.jpg
# Saved: frames/frame279.jpg
# Saved: frames/frame280.jpg
# Saved: frames/frame281.jpg
# Saved: frames/frame282.jpg
# Saved: frames/frame283.jpg
# Saved: frames/frame284.jpg
# Saved: frames/frame285.jpg
# Saved: frames/frame286.jpg
# Saved: frames/frame287.jpg
# Saved: frames/frame288.jpg
# Saved: frames/frame289.jpg
# Saved: frames/frame290.jpg
# Saved: frames/frame291.jpg
# Saved: frames/frame292.jpg
# Saved: frames/frame293.jpg
# Saved: frames/frame294.jpg
# Saved: frames/frame295.jpg
# Saved: frames/frame296.jpg
# Saved: frames/frame297.jpg
# Saved: frames/frame298.jpg
# Saved: frames/frame299.jpg
# Saved: frames/frame300.jpg
# Saved: frames/frame301.jpg
# Saved: frames/frame302.jpg
# Saved: frames/frame303.jpg
# Saved: frames/frame304.jpg
# Saved: frames/frame305.jpg
# Saved: frames/frame306.jpg
# Saved: frames/frame307.jpg
# Saved: frames/frame308.jpg
# Saved: frames/frame309.jpg
# Saved: frames/frame310.jpg
# Saved: frames/frame311.jpg
# Saved: frames/frame312.jpg
# Saved: frames/frame313.jpg
# Saved: frames/frame314.jpg
# Saved: frames/frame315.jpg
# Saved: frames/frame316.jpg
# Saved: frames/frame317.jpg
# Saved: frames/frame318.jpg
# Saved: frames/frame319.jpg
# Saved: frames/frame320.jpg
# Saved: frames/frame321.jpg
# Saved: frames/frame322.jpg
# Saved: frames/frame323.jpg
# Saved: frames/frame324.jpg
# Saved: frames/frame325.jpg
# Saved: frames/frame326.jpg
# Saved: frames/frame327.jpg
# Saved: frames/frame328.jpg
# Saved: frames/frame329.jpg
# Saved: frames/frame330.jpg
# Saved: frames/frame331.jpg
# Saved: frames/frame332.jpg
# Saved: frames/frame333.jpg
# Saved: frames/frame334.jpg
# Saved: frames/frame335.jpg
# Saved: frames/frame336.jpg
# Saved: frames/frame337.jpg
# Saved: frames/frame338.jpg
# Saved: frames/frame339.jpg
# Saved: frames/frame340.jpg
# Saved: frames/frame341.jpg
# Saved: frames/frame342.jpg
# Saved: frames/frame343.jpg
# Saved: frames/frame344.jpg
# Saved: frames/frame345.jpg
# Saved: frames/frame346.jpg
# Saved: frames/frame347.jpg
# Saved: frames/frame348.jpg
# Saved: frames/frame349.jpg
# Saved: frames/frame350.jpg
# Saved: frames/frame351.jpg
# Saved: frames/frame352.jpg
# Saved: frames/frame353.jpg
# Saved: frames/frame354.jpg
# Saved: frames/frame355.jpg
# Saved: frames/frame356.jpg
# Saved: frames/frame357.jpg
# Saved: frames/frame358.jpg
# Saved: frames/frame359.jpg
# Saved: frames/frame360.jpg
# Saved: frames/frame361.jpg
# Saved: frames/frame362.jpg
# Saved: frames/frame363.jpg
# Saved: frames/frame364.jpg
# Saved: frames/frame365.jpg
# Saved: frames/frame366.jpg
# Saved: frames/frame367.jpg
# Saved: frames/frame368.jpg
# Saved: frames/frame369.jpg
# Saved: frames/frame370.jpg
# Saved: frames/frame371.jpg
# Saved: frames/frame372.jpg
# Saved: frames/frame373.jpg
# Saved: frames/frame374.jpg
# Saved: frames/frame375.jpg
# Saved: frames/frame376.jpg
# Saved: frames/frame377.jpg
# Saved: frames/frame378.jpg
# Saved: frames/frame379.jpg
# Saved: frames/frame380.jpg
# Saved: frames/frame381.jpg
# Saved: frames/frame382.jpg
# Saved: frames/frame383.jpg
# Saved: frames/frame384.jpg
# Saved: frames/frame385.jpg
# Saved: frames/frame386.jpg
# Saved: frames/frame387.jpg
# Saved: frames/frame388.jpg
# Saved: frames/frame389.jpg
# Saved: frames/frame390.jpg
# Saved: frames/frame391.jpg
# Saved: frames/frame392.jpg
# Saved: frames/frame393.jpg
# Saved: frames/frame394.jpg
# Saved: frames/frame395.jpg
# Saved: frames/frame396.jpg
# Saved: frames/frame397.jpg
# Saved: frames/frame398.jpg
# Saved: frames/frame399.jpg
# Saved: frames/frame400.jpg
# Saved: frames/frame401.jpg
# Saved: frames/frame402.jpg
# Saved: frames/frame403.jpg
# Saved: frames/frame404.jpg
# Saved: frames/frame405.jpg
# Saved: frames/frame406.jpg
# Saved: frames/frame407.jpg
# Saved: frames/frame408.jpg
# Saved: frames/frame409.jpg
# Saved: frames/frame410.jpg
# Saved: frames/frame411.jpg
# Saved: frames/frame412.jpg
# Saved: frames/frame413.jpg
# Saved: frames/frame414.jpg
# Saved: frames/frame415.jpg
# Saved: frames/frame416.jpg
# Saved: frames/frame417.jpg
# Saved: frames/frame418.jpg
# Saved: frames/frame419.jpg
# Saved: frames/frame420.jpg
# Saved: frames/frame421.jpg
# Saved: frames/frame422.jpg
# Saved: frames/frame423.jpg
# Saved: frames/frame424.jpg
# Saved: frames/frame425.jpg
# Saved: frames/frame426.jpg
# Saved: frames/frame427.jpg
# Saved: frames/frame428.jpg
# Saved: frames/frame429.jpg
# Saved: frames/frame430.jpg
# Saved: frames/frame431.jpg
# Saved: frames/frame432.jpg
# Saved: frames/frame433.jpg
# Saved: frames/frame434.jpg
# Saved: frames/frame435.jpg
# Saved: frames/frame436.jpg
# Saved: frames/frame437.jpg
# Saved: frames/frame438.jpg
# Saved: frames/frame439.jpg
# Saved: frames/frame440.jpg
# Saved: frames/frame441.jpg
# Saved: frames/frame442.jpg
# Saved: frames/frame443.jpg
# Saved: frames/frame444.jpg
# Saved: frames/frame445.jpg
# Saved: frames/frame446.jpg
# Saved: frames/frame447.jpg
# Saved: frames/frame448.jpg
# Saved: frames/frame449.jpg
# Saved: frames/frame450.jpg
# Saved: frames/frame451.jpg
# Saved: frames/frame452.jpg
# Saved: frames/frame453.jpg
# Saved: frames/frame454.jpg
# Saved: frames/frame455.jpg
# Saved: frames/frame456.jpg
# Saved: frames/frame457.jpg
# Saved: frames/frame458.jpg
# Saved: frames/frame459.jpg
# Saved: frames/frame460.jpg
# Saved: frames/frame461.jpg
# Saved: frames/frame462.jpg
# Saved: frames/frame463.jpg
# Saved: frames/frame464.jpg
# Saved: frames/frame465.jpg
# Saved: frames/frame466.jpg
# Saved: frames/frame467.jpg
# Saved: frames/frame468.jpg
# Saved: frames/frame469.jpg
# Saved: frames/frame470.jpg
# Saved: frames/frame471.jpg
# Saved: frames/frame472.jpg
# Saved: frames/frame473.jpg
# Saved: frames/frame474.jpg
# Saved: frames/frame475.jpg
# Saved: frames/frame476.jpg
# Saved: frames/frame477.jpg
# Saved: frames/frame478.jpg
# Saved: frames/frame479.jpg
# Saved: frames/frame480.jpg
# Saved: frames/frame481.jpg
# Saved: frames/frame482.jpg
# Saved: frames/frame483.jpg
# Saved: frames/frame484.jpg
# Saved: frames/frame485.jpg
# Saved: frames/frame486.jpg
# Saved: frames/frame487.jpg
# Saved: frames/frame488.jpg
# Saved: frames/frame489.jpg
# Saved: frames/frame490.jpg
# Saved: frames/frame491.jpg
# Saved: frames/frame492.jpg
# Saved: frames/frame493.jpg
# Saved: frames/frame494.jpg
# Saved: frames/frame495.jpg
# Saved: frames/frame496.jpg
# Saved: frames/frame497.jpg
# Saved: frames/frame498.jpg
# Saved: frames/frame499.jpg
# Saved: frames/frame500.jpg
# Saved: frames/frame501.jpg
# Saved: frames/frame502.jpg
# Saved: frames/frame503.jpg
# Saved: frames/frame504.jpg
# Saved: frames/frame505.jpg
# Saved: frames/frame506.jpg
# Saved: frames/frame507.jpg
# Saved: frames/frame508.jpg
# Saved: frames/frame509.jpg
# Saved: frames/frame510.jpg
# Saved: frames/frame511.jpg
# Saved: frames/frame512.jpg
# Saved: frames/frame513.jpg
# Saved: frames/frame514.jpg
# Saved: frames/frame515.jpg
# Saved: frames/frame516.jpg
# Saved: frames/frame517.jpg
# Saved: frames/frame518.jpg
# Saved: frames/frame519.jpg
# Saved: frames/frame520.jpg
# Saved: frames/frame521.jpg
# Saved: frames/frame522.jpg
# Saved: frames/frame523.jpg
# Saved: frames/frame524.jpg
# Saved: frames/frame525.jpg
# Saved: frames/frame526.jpg
# Saved: frames/frame527.jpg
# Saved: frames/frame528.jpg
# Saved: frames/frame529.jpg
# Saved: frames/frame530.jpg
# Saved: frames/frame531.jpg
# Saved: frames/frame532.jpg
# Saved: frames/frame533.jpg
# Saved: frames/frame534.jpg
# Saved: frames/frame535.jpg
# Saved: frames/frame536.jpg
# Saved: frames/frame537.jpg
# Saved: frames/frame538.jpg
# Saved: frames/frame539.jpg
# Saved: frames/frame540.jpg
# Saved: frames/frame541.jpg
# Saved: frames/frame542.jpg
# Saved: frames/frame543.jpg
# Saved: frames/frame544.jpg
# Saved: frames/frame545.jpg
# Saved: frames/frame546.jpg
# Saved: frames/frame547.jpg
# Saved: frames/frame548.jpg
# Saved: frames/frame549.jpg
# Saved: frames/frame550.jpg
# Saved: frames/frame551.jpg
# Saved: frames/frame552.jpg
# Saved: frames/frame553.jpg
# Saved: frames/frame554.jpg
# Saved: frames/frame555.jpg
# Saved: frames/frame556.jpg
# Saved: frames/frame557.jpg
# Saved: frames/frame558.jpg
# Saved: frames/frame559.jpg
# Saved: frames/frame560.jpg
# Saved: frames/frame561.jpg
# Saved: frames/frame562.jpg
# Saved: frames/frame563.jpg
# Saved: frames/frame564.jpg
# Saved: frames/frame565.jpg
# Saved: frames/frame566.jpg
# Saved: frames/frame567.jpg
# Saved: frames/frame568.jpg
# Saved: frames/frame569.jpg
# Saved: frames/frame570.jpg
# Saved: frames/frame571.jpg
# Saved: frames/frame572.jpg
# Saved: frames/frame573.jpg
# Saved: frames/frame574.jpg
# Saved: frames/frame575.jpg
# Saved: frames/frame576.jpg
# Saved: frames/frame577.jpg
# Saved: frames/frame578.jpg
# Saved: frames/frame579.jpg
# Saved: frames/frame580.jpg
# Saved: frames/frame581.jpg
# Saved: frames/frame582.jpg
# Saved: frames/frame583.jpg
# Saved: frames/frame584.jpg
# Saved: frames/frame585.jpg
# Saved: frames/frame586.jpg
# Saved: frames/frame587.jpg
# Saved: frames/frame588.jpg
# Saved: frames/frame589.jpg
# Saved: frames/frame590.jpg
# Saved: frames/frame591.jpg
# Saved: frames/frame592.jpg
# Saved: frames/frame593.jpg
# Saved: frames/frame594.jpg
# Saved: frames/frame595.jpg
# Saved: frames/frame596.jpg
# Saved: frames/frame597.jpg
# Saved: frames/frame598.jpg
# Saved: frames/frame599.jpg
# Saved: frames/frame600.jpg
# Saved: frames/frame601.jpg
# Saved: frames/frame602.jpg
# Saved: frames/frame603.jpg
# Saved: frames/frame604.jpg
# Saved: frames/frame605.jpg
# Saved: frames/frame606.jpg
# Saved: frames/frame607.jpg
# Saved: frames/frame608.jpg
# Saved: frames/frame609.jpg
# Saved: frames/frame610.jpg
# Saved: frames/frame611.jpg
# Saved: frames/frame612.jpg
# Saved: frames/frame613.jpg
# Saved: frames/frame614.jpg
# Saved: frames/frame615.jpg
# Saved: frames/frame616.jpg
# Saved: frames/frame617.jpg
# Saved: frames/frame618.jpg
# Saved: frames/frame619.jpg
# Saved: frames/frame620.jpg
# Saved: frames/frame621.jpg
# Saved: frames/frame622.jpg
# Saved: frames/frame623.jpg
# Saved: frames/frame624.jpg
# Saved: frames/frame625.jpg
# Saved: frames/frame626.jpg
# Saved: frames/frame627.jpg
# Saved: frames/frame628.jpg
# Saved: frames/frame629.jpg
# Saved: frames/frame630.jpg
# Saved: frames/frame631.jpg
# Saved: frames/frame632.jpg
# Saved: frames/frame633.jpg
# Saved: frames/frame634.jpg
# Saved: frames/frame635.jpg
# Saved: frames/frame636.jpg
# Saved: frames/frame637.jpg
# Saved: frames/frame638.jpg
# Saved: frames/frame639.jpg
# Saved: frames/frame640.jpg
# Saved: frames/frame641.jpg
# Saved: frames/frame642.jpg
# Saved: frames/frame643.jpg
# Saved: frames/frame644.jpg
# Saved: frames/frame645.jpg
# Saved: frames/frame646.jpg
# Saved: frames/frame647.jpg
# Saved: frames/frame648.jpg
# Saved: frames/frame649.jpg
# Saved: frames/frame650.jpg
# Saved: frames/frame651.jpg
# Saved: frames/frame652.jpg
# Saved: frames/frame653.jpg
# Saved: frames/frame654.jpg
# Saved: frames/frame655.jpg
# Saved: frames/frame656.jpg
# Saved: frames/frame657.jpg
# Saved: frames/frame658.jpg
# Saved: frames/frame659.jpg
# Saved: frames/frame660.jpg
# Saved: frames/frame661.jpg
# Saved: frames/frame662.jpg
# Saved: frames/frame663.jpg
# Saved: frames/frame664.jpg
# Saved: frames/frame665.jpg
# Saved: frames/frame666.jpg
# Saved: frames/frame667.jpg
# Saved: frames/frame668.jpg
# Saved: frames/frame669.jpg
# Saved: frames/frame670.jpg
# Saved: frames/frame671.jpg
# Saved: frames/frame672.jpg
# Saved: frames/frame673.jpg
# Saved: frames/frame674.jpg
# Saved: frames/frame675.jpg
# Saved: frames/frame676.jpg
# Saved: frames/frame677.jpg
# Extracted 678 frames to frames

# %% [markdown]
# Organize the dataset

# %%
import shutil

# Create dataset folder structure
os.makedirs("dataset/images/train", exist_ok=True)
os.makedirs("dataset/images/val", exist_ok=True)
os.makedirs("dataset/images/test", exist_ok=True)

# Move extracted frames into the train folder for now
for file in os.listdir(output_dir):
    shutil.move(os.path.join(output_dir, file), "dataset/images/train")

print("Dataset organized!")
# Out:
# Dataset organized!

# %% [markdown]
# Downloading directories

# %%
import os
import shutil

# Define the target folder
target_folder = "YOLO_v8"

# Create the target folder
os.makedirs(target_folder, exist_ok=True)

# Directories to consolidate
directories = ["dataset", "frames", "sample_data", "videos"]

# Move each directory into the target folder
for dir_name in directories:
    if os.path.exists(dir_name):
        shutil.move(dir_name, os.path.join(target_folder, dir_name))
        print(f"Moved: {dir_name} -> {os.path.join(target_folder, dir_name)}")
    else:
        print(f"Directory '{dir_name}' not found, skipping...")

print(f"All directories consolidated into '{target_folder}'.")

# List the contents of the YOLO_v8 folder to verify
print("\nContents of 'YOLO_v8':")
# !ls YOLO_v8
# Out:
# Moved: dataset -> YOLO_v8/dataset
# Moved: frames -> YOLO_v8/frames
# Moved: sample_data -> YOLO_v8/sample_data
# Moved: videos -> YOLO_v8/videos
# All directories consolidated into 'YOLO_v8'.
#
# Contents of 'YOLO_v8':
# dataset  frames  sample_data  videos

# %%
# !zip -r YOLO_v8.zip YOLO_v8
# Out:
#   adding: YOLO_v8/ (stored 0%)
#   adding: YOLO_v8/sample_data/ (stored 0%)
#   adding: YOLO_v8/sample_data/README.md (deflated 39%)
#   adding: YOLO_v8/sample_data/anscombe.json (deflated 83%)
#   adding: YOLO_v8/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: YOLO_v8/sample_data/mnist_test.csv (deflated 88%)
#   adding: YOLO_v8/sample_data/california_housing_test.csv (deflated 76%)
#   adding: YOLO_v8/sample_data/california_housing_train.csv (deflated 79%)
#   adding: YOLO_v8/videos/ (stored 0%)
#   adding: YOLO_v8/videos/NA.webm (deflated 0%)
#   adding: YOLO_v8/dataset/ (stored 0%)
#   adding: YOLO_v8/dataset/images/ (stored 0%)
#   adding: YOLO_v8/dataset/images/test/ (stored 0%)
#   adding: YOLO_v8/dataset/images/val/ (stored 0%)
#   adding: YOLO_v8/dataset/images/train/ (stored 0%)
#   adding: YOLO_v8/dataset/images/train/frame381.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame465.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame475.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame36.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame584.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame117.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame108.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame412.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame347.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame602.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame34.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame335.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame161.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame565.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame595.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame202.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame68.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame581.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame383.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame284.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame377.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame422.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame109.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame362.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame192.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame62.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame619.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame510.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame64.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame329.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame458.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame442.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame276.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame184.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame553.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame676.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame181.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame285.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame7.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame65.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame429.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame514.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame8.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame102.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame268.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame327.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame300.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame350.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame614.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame216.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame38.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame605.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame437.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame546.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame74.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame551.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame450.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame537.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame254.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame199.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame552.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame355.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame261.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame60.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame172.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame348.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame542.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame541.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame462.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame23.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame495.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame411.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame562.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame451.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame548.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame375.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame658.jpg (deflated 99%)
#   adding: YOLO_v8/dataset/images/train/frame217.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame509.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame106.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame1.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame502.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame311.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame424.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame576.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame531.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame151.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame337.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame468.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame540.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame591.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame61.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame145.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame334.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame533.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame669.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame222.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame195.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame248.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame251.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame190.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame214.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame281.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame393.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame169.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame191.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame4.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame671.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame168.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame231.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame365.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame473.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame124.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame506.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame571.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame90.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame643.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame544.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame114.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame352.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame275.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame650.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame637.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame634.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame3.jpg (deflated 2%)
#   adding: YOLO_v8/dataset/images/train/frame164.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame294.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame153.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame606.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame598.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame51.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame394.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame295.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame75.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame269.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame29.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame570.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame431.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame207.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame638.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame677.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame305.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame12.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame63.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame573.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame249.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame19.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame559.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame539.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame380.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame308.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame22.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame232.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame200.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame611.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame469.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame235.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame100.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame547.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame158.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame534.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame253.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame205.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame39.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame326.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame274.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame486.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame66.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame159.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame233.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame599.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame31.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame432.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame589.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame479.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame557.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame83.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame386.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame522.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame165.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame515.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame395.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame392.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame133.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame520.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame501.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame503.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame260.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame575.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame441.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame32.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame505.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame252.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame13.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame626.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame57.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame198.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame272.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame519.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame453.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame315.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame138.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame675.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame641.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame76.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame306.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame493.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame670.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame123.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame178.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame645.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame353.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame170.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame307.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame366.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame320.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame621.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame343.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame338.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame72.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame266.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame162.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame484.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame45.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame379.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame288.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame98.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame440.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame409.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame204.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame157.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame257.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame314.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame146.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame208.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame80.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame574.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame70.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame655.jpg (deflated 99%)
#   adding: YOLO_v8/dataset/images/train/frame507.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame304.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame549.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame518.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame24.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame218.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame37.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame642.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame283.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame160.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame652.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame340.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame88.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame504.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame433.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame665.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame662.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame341.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame545.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame296.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame633.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame511.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame457.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame649.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame398.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame387.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame594.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame246.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame240.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame617.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame118.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame58.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame555.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame255.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame382.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame163.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame404.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame16.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame228.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame247.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame78.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame446.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame536.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame403.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame33.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame608.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame482.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame238.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame173.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame494.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame206.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame182.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame569.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame603.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame586.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame224.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame436.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame59.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame447.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame419.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame629.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame286.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame293.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame512.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame292.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame568.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame267.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame142.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame77.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame374.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame496.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame313.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame35.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame339.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame654.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame54.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame92.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame622.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame52.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame331.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame529.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame648.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame264.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame220.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame132.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame5.jpg (deflated 2%)
#   adding: YOLO_v8/dataset/images/train/frame444.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame490.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame492.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame535.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame112.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame287.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame406.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame346.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame328.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame360.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame126.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame310.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame21.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame657.jpg (deflated 99%)
#   adding: YOLO_v8/dataset/images/train/frame96.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame301.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame113.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame134.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame94.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame95.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame470.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame497.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame322.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame30.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame344.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame42.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame582.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame319.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame166.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame523.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame647.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame615.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame674.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame150.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame250.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame188.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame463.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame297.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame410.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame183.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame282.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame361.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame369.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame414.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame456.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame498.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame177.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame144.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame358.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame97.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame290.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame399.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame567.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame9.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame263.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame601.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame376.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame141.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame342.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame137.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame55.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame317.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame561.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame121.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame580.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame265.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame439.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame673.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame18.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame405.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame14.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame620.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame372.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame636.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame627.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame321.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame400.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame639.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame480.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame508.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame640.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame623.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame336.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame26.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame538.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame543.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame389.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame128.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame185.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame351.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame156.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame672.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame28.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame474.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame47.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame56.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame129.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame521.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame663.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame487.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame467.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame421.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame370.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame660.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame488.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame85.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame318.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame524.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame302.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame215.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame213.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame41.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame378.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame438.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame471.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame426.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame103.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame17.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame666.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame239.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame661.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame167.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame312.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame236.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame49.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame277.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame610.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame186.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame558.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame333.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame577.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame459.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame193.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame87.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame149.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame210.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame452.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame176.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame148.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame299.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame367.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame499.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame273.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame656.jpg (deflated 99%)
#   adding: YOLO_v8/dataset/images/train/frame110.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame99.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame203.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame560.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame425.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame384.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame485.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame2.jpg (deflated 2%)
#   adding: YOLO_v8/dataset/images/train/frame368.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame612.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame579.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame0.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame483.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame69.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame324.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame664.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame413.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame578.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame289.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame618.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame107.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame262.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame81.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame325.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame211.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame11.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame415.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame607.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame86.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame241.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame82.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame136.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame402.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame6.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame359.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame385.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame174.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame566.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame155.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame127.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame391.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame152.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame115.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame258.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame363.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame154.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame517.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame423.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame256.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame196.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame417.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame330.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame477.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame651.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame550.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame298.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame111.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame526.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame291.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame466.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame530.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame197.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame194.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame122.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame53.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame613.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame227.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame585.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame449.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame271.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame143.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame408.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame635.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame563.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame219.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame631.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame43.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame564.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame461.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame420.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame616.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame628.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame588.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame434.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame40.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame221.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame668.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame525.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame130.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame175.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame44.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame242.jpg (deflated 2%)
#   adding: YOLO_v8/dataset/images/train/frame604.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame443.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame454.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame225.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame212.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame280.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame73.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame187.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame653.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame323.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame609.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame587.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame448.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame237.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame464.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame527.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame20.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame270.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame259.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame407.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame590.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame93.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame67.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame303.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame397.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame209.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame532.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame104.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame48.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame445.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame435.jpg (deflated 2%)
#   adding: YOLO_v8/dataset/images/train/frame243.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame223.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame371.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame401.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame180.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame596.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame583.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame460.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame489.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame513.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame592.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame481.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame390.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame418.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame105.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame91.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame179.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame139.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame667.jpg (deflated 100%)
#   adding: YOLO_v8/dataset/images/train/frame89.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame131.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame345.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame597.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame10.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame476.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame125.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame388.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame234.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame624.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame119.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame201.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame27.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame427.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame528.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame396.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame309.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame278.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame659.jpg (deflated 99%)
#   adding: YOLO_v8/dataset/images/train/frame279.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame189.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame625.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame101.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame245.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame244.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame478.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame332.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame229.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame226.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame15.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame430.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame632.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame600.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame84.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame455.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame354.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame491.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame116.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame428.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame171.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame71.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame630.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame25.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame316.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame120.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame416.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame472.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame147.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame349.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame373.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame554.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame593.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame356.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame556.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame644.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame357.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame572.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame500.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame135.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame79.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame140.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame46.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame646.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame516.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame230.jpg (deflated 0%)
#   adding: YOLO_v8/dataset/images/train/frame50.jpg (deflated 1%)
#   adding: YOLO_v8/dataset/images/train/frame364.jpg (deflated 0%)
#   adding: YOLO_v8/frames/ (stored 0%)

# %%
from google.colab import files
files.download("YOLO_v8.zip")

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Copy the file to your Google Drive
# !cp YOLO_v8.zip /content/drive/MyDrive/YOLO_v8.zip

print("File has been copied to Google Drive in 'My Drive' as 'YOLO_v8.zip'")
# Out:
# Mounted at /content/drive
# File has been copied to Google Drive in 'My Drive' as 'YOLO_v8.zip'

# %%
# !du -h YOLO_v8.zip
# Out:
# 2.5G	YOLO_v8.zip

# %% [markdown]
# Importing directly into roboflow (not working)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CDDO05uGHWiWIGcIMvjI")

workspace = rf.workspace("correct_workspace_name")  # Replace with the verified workspace name
for project in workspace.projects():
    print("Project Name:", project.name)
# Out:
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# <ipython-input-30-36425c8c847d> in <cell line: 0>()
#       2 rf = Roboflow(api_key="CDDO05uGHWiWIGcIMvjI")
#       3
# ----> 4 workspace = rf.workspace("correct_workspace_name")  # Replace with the verified workspace name
#       5 for project in workspace.projects():
#       6     print("Project Name:", project.name)
#
# /usr/local/lib/python3.11/dist-packages/roboflow/__init__.py in workspace(self, the_workspace)
#     241         if self.api_key:  # Check if api_key was passed during __init__
#     242             api_key = self.api_key
# --> 243             list_projects = rfapi.get_workspace(api_key, the_workspace)
#     244             return Workspace(list_projects, api_key, the_workspace, self.model_format)
#     245
#
# /usr/local/lib/python3.11/dist-packages/roboflow/adapters/rfapi.py in get_workspace(api_key, workspace_url)
#      34     response = requests.get(url)
#      35     if response.status_code != 200:
# ---> 36         raise RoboflowError(response.text)
#      37     result = response.json()
#      38     return result
#
# RoboflowError: {
#     "error": {
#         "message": "Unsupported get request. Workspace with ID \"correct_workspace_name\" does not exist or cannot be loaded due to missing permissions.",
#         "status": 404,
#         "type": "GraphMethodException",
#         "hint": "You can see your available workspaces by issuing a GET request to /workspaces"
#     }
# }

# %% [markdown]
# Upload Roboflow Dataset

# %%
# Upload your dataset ZIP file
from google.colab import files
uploaded = files.upload()

# Unzip the dataset
# !unzip dataset.zip -d dataset

# %% [markdown]
# Train Model

# %%
# Import YOLO and train the model
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO('yolov8n.pt')  # Use 'yolov8n.pt' (nano) for faster training

# Train the model
model.train(data='dataset/data.yaml', epochs=20, imgsz=640)

# %% [markdown]
# Visualize the Results

# %%
from IPython.display import Image

# Confusion matrix
Image(filename='runs/detect/train/confusion_matrix.png')

# Loss and metrics graphs
Image(filename='runs/detect/train/results.png')

# %%
# !ls
# Out:
# dataset  frames  sample_data  videos
